# %%
"""Sample Notebook for feature detection with OpenCV"""
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img=cv2.imread("/home/hariharan/Desktop/Styrac/DSC09941.JPG")
img3=cv2.imread("/home/hariharan/Desktop/Projects/ORB_SLAM2_dense/frame0075.jpg")
# Initiate STAR detector
#orb = cv2.ORB_create(20000)
#orb = cv2.AKAZE_create()
#orb =cv2.xfeatures2d.SIFT_create(20000)
# find the keypoints with ORB,AKAZE or SIFT
kp = orb.detect(img,None)

# compute the descriptors with ORB
kp, des = orb.compute(img, kp)

print(len(kp))
# draw only keypoints location,not size and orientation
img2=img
cv2.drawKeypoints(img,kp,img2,color=(0,255,0))
plt.imshow(img2),plt.show()
# Out:
# 1156
# (<matplotlib.image.AxesImage at 0x7f949fa88080>, None)
